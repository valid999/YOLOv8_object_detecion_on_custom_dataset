# %% [markdown]
# <a href="https://colab.research.google.com/github/valid999/YOLOv8_object_detecion_on_custom_dataset/blob/main/Yolov8_object_detections_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installation

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Computer_vision_project/Yolo_v8_Object_Detection
# Out:
# /content/drive/MyDrive/Computer_vision_project/Yolo_v8_Object_Detection

# %%
# !ls
# Out:
# data.yaml  test  train	valid

# %%
# %cd /content/drive/MyDrive/Computer_vision_project/Yolo_v8_Object_Detection

# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=25 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/Computer_vision_project/Yolo_v8_Object_Detection
# ...
# 100% 21.5M/21.5M [00:00<00:00, 147MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					     results.png	    val_batch0_pred.jpg
# confusion_matrix.png				     train_batch0.jpg	    val_batch1_labels.jpg
# events.out.tfevents.1700332536.38415ac1981c.15437.0  train_batch120.jpg     val_batch1_pred.jpg
# F1_curve.png					     train_batch121.jpg     val_batch2_labels.jpg
# P_curve.png					     train_batch122.jpg     val_batch2_pred.jpg
# PR_curve.png					     train_batch1.jpg	    weights
# R_curve.png					     train_batch2.jpg
# results.csv					     val_batch0_labels.jpg

# %%
Image(filename = 'runs/detect/train/confusion_matrix.png' , width = 800)

# %%
Image(filename = 'runs/detect/train/results.png')

# %%
Image(filename = 'runs/detect/train/val_batch0_pred.jpg' , width = 600)

# %% [markdown]
# ### The predictions part

# %%
Image(filename = 'runs/detect/train/val_batch1_pred.jpg' , width = 600)

# %% [markdown]
# ## The labels part of the images

# %%
 Image(filename = 'runs/detect/train/val_batch1_labels.jpg' , width = 600)

# %% [markdown]
# ## Inference of the cusmtom model

# %%
# !yolo task=detect mode=predict model= runs/detect/train/weights/best.pt conf = 0.25 source = /content/drive/MyDrive/Computer_vision_project/Yolo_v8_Object_Detection/test/images
# Out:
# 2023-11-18 19:02:52.568045: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-18 19:02:52.568103: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-18 19:02:52.568137: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-18 19:02:53.593452: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/Computer_vision_project/Yolo_v8_Object_Detection/test/images/*.jpg')[:3]:

      display(Image(filename=image_path, width=600))
      print("\n")
      # print(image_path)
